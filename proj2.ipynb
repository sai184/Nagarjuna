# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv('zomato.csv')

# %%
dataset
# Out:
#       Average_Cost_for_two Table_booking Online_delivery delivering_now  \
# 0                     1100           Yes              No             No
# 1                     1200           Yes              No             No
# 2                     4000           Yes              No             No
# 3                     1500            No              No             No
# 4                     1500           Yes              No             No
# 5                     1000            No              No             No
# 6                     2000           Yes              No             No
# 7                     2000           Yes              No             No
# 8                     6000           Yes              No             No
# 9                     1100           Yes              No             No
# 10                     800            No              No             No
# 11                     900           Yes              No             No
# 12                     800            No              No             No
# 13                    1000           Yes              No             No
# 14                     700            No              No             No
# 15                     800            No              No             No
# 16                     850            No              No             No
# 17                    1200           Yes              No             No
# 18                     600            No              No             No
# 19                    1500           Yes              No             No
# 20                    3000           Yes              No             No
# 21                    1800           Yes              No             No
# 22                      55            No              No             No
# 23                      30            No              No             No
# 24                      45            No              No             No
# 25                      60            No              No             No
# 26                      50            No              No             No
# 27                      80            No              No             No
# 28                      90            No              No             No
# 29                     200            No              No             No
# ...                    ...           ...             ...            ...
# 9521                    50            No              No             No
# 9522                   100            No              No             No
# 9523                    60            No              No             No
# 9524                    80            No              No             No
# 9525                   150            No              No             No
# 9526                   400            No              No             No
# 9527                    60            No              No             No
# 9528                    70            No              No             No
# 9529                    40            No              No             No
# 9530                    50            No              No             No
# 9531                    80            No              No             No
# 9532                   100            No              No             No
# 9533                    50            No              No             No
# 9534                    70            No              No             No
# 9535                    70            No              No             No
# 9536                    40            No              No             No
# 9537                    50            No              No             No
# 9538                    30            No              No             No
# 9539                    80            No              No             No
# 9540                   130            No              No             No
# 9541                    75            No              No             No
# 9542                    80            No              No             No
# 9543                    35            No              No             No
# 9544                    40            No              No             No
# 9545                    90            No              No             No
# 9546                    80            No              No             No
# 9547                   105            No              No             No
# 9548                   170            No              No             No
# 9549                   120            No              No             No
# 9550                    55            No              No             No
#
#       Price_range  Aggregate_rating Rating_color Rating_text  Votes
# 0               3               4.8   Dark Green   Excellent    314
# 1               3               4.5   Dark Green   Excellent    591
# 2               4               4.4        Green   Very Good    270
# 3               4               4.9   Dark Green   Excellent    365
# 4               4               4.8   Dark Green   Excellent    229
# 5               3               4.4        Green   Very Good    336
# 6               4               4.0        Green   Very Good    520
# 7               4               4.2        Green   Very Good    677
# 8               4               4.9   Dark Green   Excellent    621
# 9               3               4.8   Dark Green   Excellent    532
# 10              3               4.9   Dark Green   Excellent   1070
# 11              3               4.2        Green   Very Good    488
# 12              3               4.8   Dark Green   Excellent    294
# 13              3               4.2        Green   Very Good    458
# 14              3               4.3        Green   Very Good    223
# 15              3               3.6       Yellow        Good     29
# 16              3               4.0        Green   Very Good     72
# 17              3               4.5   Dark Green   Excellent    211
# 18              2               4.5   Dark Green   Excellent    118
# 19              4               4.4        Green   Very Good    392
# 20              4               4.7   Dark Green   Excellent    535
# 21              4               4.5   Dark Green   Excellent    618
# 22              2               3.0       Orange     Average      6
# 23              1               3.8       Yellow        Good      9
# 24              2               3.7       Yellow        Good     11
# 25              3               3.8       Yellow        Good     11
# 26              2               3.2       Orange     Average     11
# 27              3               3.1       Orange     Average     10
# 28              3               3.7       Yellow        Good      8
# 29              4               3.7       Yellow        Good      5
# ...           ...               ...          ...         ...    ...
# 9521            2               3.4       Orange     Average    115
# 9522            3               4.5   Dark Green   Excellent    231
# 9523            3               4.4        Green   Very Good    296
# 9524            3               4.9   Dark Green   Excellent     95
# 9525            4               4.4        Green   Very Good    115
# 9526            4               4.1        Green   Very Good     97
# 9527            3               4.3        Green   Very Good    106
# 9528            3               4.2        Green   Very Good     79
# 9529            2               4.6   Dark Green   Excellent    109
# 9530            2               4.4        Green   Very Good     72
# 9531            3               3.8       Yellow        Good    123
# 9532            3               4.2        Green   Very Good    103
# 9533            2               4.3        Green   Very Good    103
# 9534            3               4.4        Green   Very Good    131
# 9535            3               4.2        Green   Very Good    152
# 9536            2               4.7   Dark Green   Excellent    104
# 9537            2               4.7   Dark Green   Excellent   1311
# 9538            2               4.9   Dark Green   Excellent   1042
# 9539            3               4.2        Green   Very Good    874
# 9540            4               4.9   Dark Green   Excellent    522
# 9541            3               4.2        Green   Very Good    877
# 9542            3               3.7       Yellow        Good    506
# 9543            2               4.5   Dark Green   Excellent    761
# 9544            2               4.7   Dark Green   Excellent   1305
# 9545            3               4.3        Green   Very Good    870
# 9546            3               4.1        Green   Very Good    788
# 9547            3               4.2        Green   Very Good   1034
# 9548            4               3.7       Yellow        Good    661
# 9549            4               4.0        Green   Very Good    901
# 9550            2               4.0        Green   Very Good    591
#
# [9551 rows x 9 columns]

# %%
x=dataset.iloc[:,4:-3].values

# %%
x
# Out:
# array([[3. , 4.8],
#        [3. , 4.5],
#        [4. , 4.4],
#        ...,
#        [4. , 3.7],
#        [4. , 4. ],
#        [2. , 4. ]])

# %%
y=dataset.iloc[:,-1].values

# %%
y
# Out:
# array([314, 591, 270, ..., 661, 901, 591], dtype=int64)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train
# Out:
# array([[1. , 0. ],
#        [1. , 2.9],
#        [1. , 3.2],
#        ...,
#        [2. , 0. ],
#        [1. , 4. ],
#        [2. , 2.5]])

# %%
x_test
# Out:
# array([[2. , 3.1],
#        [4. , 3.5],
#        [2. , 3.7],
#        ...,
#        [1. , 3.7],
#        [1. , 0. ],
#        [2. , 2.7]])

# %%
y_train
# Out:
# array([  0,   4,  16, ...,   0, 169,  41], dtype=int64)

# %%
y_test
# Out:
# array([  8, 706,  33, ..., 223,   2,   7], dtype=int64)

# %%
from sklearn.linear_model import LinearRegression
mr=LinearRegression()

# %%
mr.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
y_predict=mr.predict(x_test)

# %%
y_predict
# Out:
# array([205.79673501, 439.15152705, 243.55007   , ..., 139.45711898,
#        -93.35511347, 180.62784502])

# %%
mr.predict(np.array([[3,4.8]]))
# Out:
# array([416.85746851])

# %%
plt.scatter(x_test[:,0],y_predict)

# %%
plt.scatter(x_test[:,1],y_predict)
